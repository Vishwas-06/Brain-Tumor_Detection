# %% [raw]
# Gade Vishwas

# %% [raw]
# BL.EN.U4AIE20013

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1], [2], [3]]) 


# 1 - Normal
# 2 - Pitutiary Tumor
# 3 - Glioma Tumor
# 4 - Meningioma Tumor
# Out:
# OneHotEncoder()

# %%
# This cell updates result list for images with tumor

data1 = []
paths = []
result = []

for r, d, f in os.walk(r"E:\Downloads HDD\archive (4)\Training\notumor"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data1.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images Pitutiary Tumor

paths = []
for r, d, f in os.walk(r"E:\Downloads HDD\archive (4)\Training\pituitary"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data1.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 9>()
#      12 img = np.array(img)
#      13 if(img.shape == (128,128,3)):
# ---> 14     data1.append(np.array(img))
#      15     result.append(encoder.transform([[1]]).toarray())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
# This cell updates result list for images Glioma Tumor

paths = []
for r, d, f in os.walk(r"E:\Downloads HDD\archive (4)\Training\glioma"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data1.append(np.array(img))
        result.append(encoder.transform([[2]]).toarray())

# %%
# This cell updates result list for images Meningioma Tumor

paths = []
for r, d, f in os.walk(r"E:\Downloads HDD\archive (4)\Training\meningioma"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data1.append(np.array(img))
        result.append(encoder.transform([[3]]).toarray())

# %%
data1 = np.array(data1)
data1.shape

# %%
result = np.array(result)
result = result.reshape(3236,4)

# %%
x_train,x_test,y_train,y_test = train_test_split(data1, result, test_size=0.3, shuffle=True, random_state=0)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(4, 4), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(4, 4),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(4, 4)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (4,4), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (4,4), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(4,4), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='sigmoid'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())

# %%
y_train.shape

# %%
history = model.fit(x_train, y_train, epochs = 20, batch_size = 200, verbose = 1,validation_data = (x_test, y_test))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
def names(number):
    if number==0:
        return 'no Tumor'
    elif number==1:
        return 'Its a Piutiary tumor'
    elif number==2:
        return 'ts a Glioma tumor'
    elif number==3:
        return 'Its a Meningioma tumor'

# %%
from tkinter import *
from PIL import ImageTk,Image
from tkinter.filedialog import askopenfilename
from tkinter import messagebox
from tkinter import ttk
from matplotlib.pyplot import imshow

root=Tk()
root.title('Text Summarization')
root.geometry("500x500")

my_notebook = ttk.Notebook(root)
my_notebook.pack(pady=15)

my_frame1 = Frame(my_notebook,width=500,height=500)

my_frame1.pack(fill="both",expand=1)


my_notebook.add(my_frame1, text="Tab1")

Brain_scan=[]


def myclick1():
    my_frame2 = Frame(my_notebook,width=500,height=500)
    my_frame2.pack(fill="both",expand=1)
    my_notebook.add(my_frame2, text="tab2")
    my_notebook.hide(0)
    e=Entry(my_frame2,width=50)
    e.pack(side=TOP)
    Label(my_frame2,text="Enter your Name").pack()
    Button(my_frame2,text="Enter", command=myclick2).pack()
    
def myclick2():
    my_frame3 = Frame(my_notebook,width=500,height=500)
    my_frame3.pack(fill="both",expand=1)
    my_notebook.add(my_frame3, text="tab2")
    my_notebook.hide(1)
    mylabel =Label(my_frame3,text="Thanks for Using our system").pack(pady=20)
    Button(my_frame3,text="Click to proceed", command=popup).pack()
    
def open_txt():
    my_frame6 = Frame(my_notebook,width=500,height=500)
    my_frame6.pack(fill="both",expand=1)
    my_notebook.add(my_frame6, text="tab2")
    my_notebook.hide(4)
    my_text=Text(my_frame6,width=40,height=10,font=("Helvetica",16))
    my_text.pack(pady=20)
    img = Image.open(Brain_scan[0])
    x = np.array(img.resize((128,128)))
    x = x.reshape(1,128,128,3)
    res = model.predict_on_batch(x)
    classification = np.where(res == np.amax(res))[1][0]
    file1 = open("E:\Downloads HDD\sample_1.txt","w")
    L1 = [str(res[0][classification]*100) + '% Confidence This Is ' + names(classification)]
    file1.write("Your Result :\n")
    file1.writelines(L1[0])
    file1.close()    
    text_file = open("E:\Downloads HDD\sample_1.txt", 'r')
    stuff = text_file.read()
    my_text.insert(END,stuff)
    text_file.close()
    global my_image
    my_image =ImageTk.PhotoImage(file=Brain_scan[0])
    my_text.image_create(END, image=my_image)
     
  
    
    
def popup():
    my_frame4 = Frame(my_notebook,width=500,height=500)
    my_frame4.pack(fill="both",expand=1)
    my_notebook.add(my_frame4, text="tab2")
    my_notebook.hide(2)
    response=messagebox.askyesno("SELECT UR OPTION","DO U HAVE UR BRAIN SCAN?")
    
    #Label(root, text=response).pack()
    if response == 1 :
        

        my_frame5 = Frame(my_notebook,width=500,height=500)
        my_frame5.pack(fill="both",expand=1)
        my_notebook.add(my_frame5, text="tab2")
        my_notebook.hide(3)
        link = askopenfilename()
        Brain_scan.append(link)
       
        Label(my_frame5, text="Uploaded sucessfully").pack()
        Button(my_frame5,text="View Results",command = open_txt).pack(pady=20)
    else: 
        my_frame5 = Frame(my_notebook,width=500,height=500)
        my_frame5.pack(fill="both",expand=1)
        my_notebook.add(my_frame5, text="tab2")
        my_notebook.hide(3)
        Label(my_frame5,text="you need brain scan to find type of tumor").pack()


#open_button = Button(root,text="View Results",command = open_txt).pack(pady=20)
#open_button.pack(pady=20)
Label(my_frame1,text="HI Welcome to Brain tumor detection System").pack()
Button(my_frame1,text="click here to proceed", command=myclick1).pack()
root.mainloop()

# %%
from tkinter import *
from PIL import ImageTk,Image
from tkinter.filedialog import askopenfilename
from tkinter import messagebox
from tkinter import ttk
from matplotlib.pyplot import imshow

root=Tk()
root.title('Bio Project')
root.geometry("750x750")

my_notebook = ttk.Notebook(root)
my_notebook.pack(pady=15)

my_frame1 = Frame(my_notebook,width=500,height=500)

my_frame1.pack(fill="both",expand=1)


my_notebook.add(my_frame1, text="Tab1")

Brain_scan=[]
classification_type=[]



def myclick1():
    my_frame2 = Frame(my_notebook,width=500,height=500)
    my_frame2.pack(fill="both",expand=1)
    my_notebook.add(my_frame2, text="tab2")
    my_notebook.hide(0)
    e=Entry(my_frame2,width=50)
    e.pack(side=TOP)
    Label(my_frame2,text="Enter your Name").pack()
    Button(my_frame2,text="Enter", command=myclick2).pack()
    
def myclick2():
    my_frame3 = Frame(my_notebook,width=500,height=500)
    my_frame3.pack(fill="both",expand=1)
    my_notebook.add(my_frame3, text="tab3")
    my_notebook.hide(1)
    mylabel =Label(my_frame3,text="Thanks for Using our system").pack(pady=20)
    Button(my_frame3,text="Click to proceed", command=popup).pack()
    

def open_txt1():
    if classification_type[0]==0:
        my_frame6 = Frame(my_notebook,width=500,height=500)
        my_frame6.pack(fill="both",expand=1)
        my_notebook.add(my_frame6, text="tab6")              
        my_notebook.hide(4)
        my_text=Text(my_frame6,width=40,height=10,font=("Helvetica",16))
        my_text.pack(fill="both",expand=1)
        text_file = open("E:\Downloads HDD\sample_1.txt", 'r')
        stuff = text_file.read()
        my_text.insert(END,stuff)
        text_file.close()
        global my_image1
        my_image1 =ImageTk.PhotoImage(file=Brain_scan[0])
        my_text.image_create(END, image=my_image1)
    
    elif classification_type[0]==1:
        my_frame6 = Frame(my_notebook,width=500,height=500)
        my_frame6.pack(fill="both",expand=1)
        my_notebook.add(my_frame6, text="tab2")              
        my_notebook.hide(4)
        my_text=Text(my_frame6,width=40,height=10,font=("Helvetica",16))
        my_text.pack(fill="both",expand=1)
        text_file = open("E:\Downloads HDD\pituitary.txt", 'r')
        stuff = text_file.read()
        my_text.insert(END,stuff)
        text_file.close()
        global my_image2
        my_image2 =ImageTk.PhotoImage(file=Brain_scan[0])
        my_text.image_create(END, image=my_image2)
             
    elif classification_type[0]==2:
        my_frame6 = Frame(my_notebook,width=500,height=500)
        my_frame6.pack(fill="both",expand=1)
        my_notebook.add(my_frame6, text="tab2")              
        my_notebook.hide(4)
        my_text=Text(my_frame6,width=40,height=10,font=("Helvetica",16))
        my_text.pack(fill="both",expand=2)
        text_file = open("E:\Downloads HDD\Glioma _1.txt", 'r')
        stuff = text_file.read()
        my_text.insert(END,stuff)
        text_file.close()
        global my_image3
        my_image3 =ImageTk.PhotoImage(file=Brain_scan[0])
        my_text.image_create(END, image=my_image3)
             
    elif classification_type[0]==3:
        my_frame6 = Frame(my_notebook,width=500,height=500)
        my_frame6.pack(fill="both",expand=1)
        my_notebook.add(my_frame6, text="tab2")              
        my_notebook.hide(4)
        my_text=Text(my_frame6,width=40,height=10,font=("Helvetica",16))
        my_text.pack(fill="both",expand=1)
        text_file = open("E:\Downloads HDD\Meningioma.txt", 'r')
        stuff = text_file.read()
        my_text.insert(END,stuff)
        text_file.close()
        global my_image4
        my_image4 =ImageTk.PhotoImage(file=Brain_scan[0])
        my_text.image_create(END, image=my_image4)
  
    
    
def popup():
    my_frame4 = Frame(my_notebook,width=500,height=500)
    my_frame4.pack(fill="both",expand=1)
    my_notebook.add(my_frame4, text="tab4")
    my_notebook.hide(2)
    response=messagebox.askyesno("SELECT UR OPTION","DO U HAVE UR BRAIN SCAN?")
    
    #Label(root, text=response).pack()
    if response == 1 :
        

        my_frame5 = Frame(my_notebook,width=500,height=500)
        my_frame5.pack(fill="both",expand=1)
        my_notebook.add(my_frame5, text="tab5")
        my_notebook.hide(3)
        link = askopenfilename()
        Brain_scan.append(link)
        
        img = Image.open(Brain_scan[0])
        x = np.array(img.resize((128,128)))
        x = x.reshape(1,128,128,3)
        res = model.predict_on_batch(x)
        classification = np.where(res == np.amax(res))[1][0]        
        a=classification
        val = np.int64(a)
        pyval = val.item()
        classification_type.append(pyval)
        Label(my_frame5, text="uploaded successfully").pack()
        Button(my_frame5,text="View Results",command = open_txt1).pack(pady=20)
    else: 
        my_frame5 = Frame(my_notebook,width=500,height=500)
        my_frame5.pack(fill="both",expand=1)
        my_notebook.add(my_frame5, text="tab2")
        my_notebook.hide(3)
        Label(my_frame5,text="you need brain scan to find type of tumor").pack()


#open_button = Button(root,text="View Results",command = open_txt).pack(pady=20)
#open_button.pack(pady=20)
Label(my_frame1,text="HI Welcome to Brain tumor detection System").pack()
Button(my_frame1,text="click here to proceed", command=myclick1).pack()
root.mainloop()

# %%
img = Image.open(r"E:\Downloads HDD\archive (4)\Testing\meningioma\Te-me_0026.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]        
a=classification
print(a)
val = np.int64(a)
pyval = val.item()
classification_type.append(pyval)
type_of_tumor=classification_type[0]
print(type_of_tumor)
